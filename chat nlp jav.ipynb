# %%
# %% Global Variables
datasetPath = "./TM-3-2020/data/"
sourceCodePath = './src'

# %%
# %% libraries
import numpy as np
import pandas as pd
import os
import sys
import re
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
import matplotlib 
import torch

# %%
# %% Loads Source code
sys.path.append(os.path.join(os.getcwd(), sourceCodePath))

# %%
# local library
# rm -fr src/chat/__pycache__
# rm -fr src/chat/cbow/__pycache__
# rm -fr src/chat/dataset/__pycache__
# rm -fr src/chat/functions/__pycache__

import chat as ch

# %%
# %% system dependencies
# !pip install torch
# !pip install transformers

# %%
# %% 
from transformers import AutoTokenizer

# %%
# %% Loads Dataset
dataset = ch.dataset.Dataset(datasetPath)

# %%
# %%
df = dataset.get_dataframe()
df.head()
# Out:
#                             conversation_id  \
# 0  dlg-bca5ce0a-056f-446e-be94-3ba77b32a84f
# 1  dlg-bd494e2c-36f6-4529-8e4d-d5c4d64388ae
# 2  dlg-c9064676-75fe-4d0a-83c2-497e1f2115a6
# 3  dlg-f7500bcf-472c-48c3-adfd-e4ec9f63bcf1
# 4  dlg-df1f0d45-27f2-4fb0-8aaa-b6b5f5a843bb
#
#                                   scenario  \
# 0  auto template 1 with theater name error
# 1  auto template 1 with theater name error
# 2  auto template 1 with theater name error
# 3  auto template 1 with theater name error
# 4  auto template 1 with theater name error
#
#                                         instructions  \
# 0  scenario: in the conversation below, a custome...
# 1  scenario: in the conversation below, a custome...
# 2  scenario: in the conversation below, a custome...
# 3  scenario: in the conversation below, a custome...
# 4  scenario: in the conversation below, a custome...
#
#                                         conversation intent success
# ...

# %%
# %%
df['scenario'].value_counts().plot.pie(title="Distribution of Sub categories", figsize=(20, 30))
# Out:
# <AxesSubplot:title={'center':'Distribution of Sub categories'}, ylabel='scenario'>

# %%
df['scenario'].value_counts().plot.barh(color="red", title="Scenarios", y=100, figsize=(10, 10))
# Out:
# <AxesSubplot:title={'center':'Scenarios'}>

# %%
intent_count = df['intent'].value_counts()
intent_count
# Out:
# buy               16426
# change             4253
# recommendation     2859
#                     219
# Name: intent, dtype: int64

# %%
intent_count.plot.pie(title="Distribution of Intents", figsize=(10, 10))
# Out:
# <AxesSubplot:title={'center':'Distribution of Intents'}, ylabel='intent'>

# %%
intent_count.plot.barh(color="red", title="Scenarios", y=100, figsize=(10, 10))
# Out:
# <AxesSubplot:title={'center':'Scenarios'}>

# %%
df.to_csv('dataset.csv')
